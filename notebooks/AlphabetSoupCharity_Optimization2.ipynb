# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN'
application_df.drop(columns=['EIN'], inplace=True)

# %%
# Determine the number of unique values in each column.
application_df.nunique()
# Out:
# NAME                      19568
# APPLICATION_TYPE             17
# AFFILIATION                   6
# CLASSIFICATION               71
# USE_CASE                      5
# ORGANIZATION                  4
# STATUS                        2
# INCOME_AMT                    9
# SPECIAL_CONSIDERATIONS        2
# ASK_AMT                    8747
# IS_SUCCESSFUL                 2
# dtype: int64

# %%
# Look at NAME value counts to identify for binning
name_counts = application_df['NAME'].value_counts()
name_counts
# Out:
# NAME
# PARENT BOOSTER USA INC                                                  1260
# TOPS CLUB INC                                                            765
# UNITED STATES BOWLING CONGRESS INC                                       700
# WASHINGTON STATE UNIVERSITY                                              492
# AMATEUR ATHLETIC UNION OF THE UNITED STATES INC                          408
#                                                                         ...
# ST LOUIS SLAM WOMENS FOOTBALL                                              1
# AIESEC ALUMNI IBEROAMERICA CORP                                            1
# WEALLBLEEDRED ORG INC                                                      1
# AMERICAN SOCIETY FOR STANDARDS IN MEDIUMSHIP & PSYCHICAL INVESTIGATI       1
# WATERHOUSE CHARITABLE TR                                                   1
# Name: count, Length: 19568, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `names_to_replace`
names_to_replace = list(name_counts[name_counts < 50].index)

# Replace in dataframe
for name in names_to_replace:
    application_df['NAME'] = application_df['NAME'].replace(name,"Other")

# Check to make sure replacement was successful
application_df['NAME'].value_counts()
# Out:
# NAME
# Other                                                                 24545
# PARENT BOOSTER USA INC                                                 1260
# TOPS CLUB INC                                                           765
# UNITED STATES BOWLING CONGRESS INC                                      700
# WASHINGTON STATE UNIVERSITY                                             492
# AMATEUR ATHLETIC UNION OF THE UNITED STATES INC                         408
# PTA TEXAS CONGRESS                                                      368
# SOROPTIMIST INTERNATIONAL OF THE AMERICAS INC                           331
# ALPHA PHI SIGMA                                                         313
# TOASTMASTERS INTERNATIONAL                                              293
# MOST WORSHIPFUL STRINGER FREE AND ACCEPTED MASONS                       287
# LITTLE LEAGUE BASEBALL INC                                              277
# INTERNATIONAL ASSOCIATION OF LIONS CLUBS                                266
# MOMS CLUB                                                               210
# INTERNATIONAL ASSOCIATION OF SHEET METAL AIR RAIL & TRANSPORTATION      206
# AMERICAN ASSOCIATION OF UNIVERSITY WOMEN                                197
# FARMERS EDUCATIONAL AND COOPERATIVE UNION OF AMERICA                    166
# KNIGHTS OF COLUMBUS                                                     158
# HABITAT FOR HUMANITY INTERNATIONAL INC                                  154
# TENNESSEE ORDER OF THE EASTERN STAR                                     151
# VETERANS OF FOREIGN WARS OF THE UNITED STATES AUXILIARY                 144
# PTA UTAH CONGRESS                                                       140
# THE UNITED STATES PONY CLUBS INC                                        136
# CIVITAN INTERNATIONAL                                                   131
# SIGMA BETA DELTA INC                                                    127
# MONTANA 4-H FOUNDATION INC                                              107
# HONOR SOCIETY OF PHI KAPPA PHI                                          107
# WASHINGTON STATE GRANGE                                                 106
# UNIVERSITY OF WYOMING                                                   105
# DEMOLAY INTERNATIONAL                                                   104
# SERTOMA INC                                                             103
# AIR FORCE ASSOCIATION                                                    99
# WORKERS UNITED                                                           97
# GAMMA THETA UPSILON                                                      92
# INTERNATIONAL ASSOCIATION OF FIRE FIGHTERS                               91
# SOCIETY OF SAINT VINCENT DE PAUL COUNCIL OF LOS ANGELES                  87
# ROTARY INTERNATIONAL                                                     84
# CALIFORNIA GARDEN CLUBS INC                                              76
# SWEET ADELINES INTERNATIONAL                                             73
# DISABLED AMERICAN VETERANS                                               73
# KLEIN SUPPORT GROUPS INC                                                 69
# CLEARCREEK I S D SUPPORT GROUPS                                          60
# VFW AUXILIARY DEPARTMENT OF OKLAHOMA INC                                 58
# CISD EDUCATIONAL SUPPORT GROUPS INC                                      57
# DEPARTMENT OF KANSAS LADIES AUXILIARY TO THE VFW OF THE US INC           57
# SONS OF CONFEDERATE VETERANS INC                                         56
# SLOW FOOD USA INC                                                        55
# NATIONAL YOUNG MENS SERVICE LEAGUE                                       54
# AMATEUR ATHLETIC UNION OF THE UNITED STATES                              52
# LAMBDA THETA ALPHA                                                       52
# UNITED FEDERATION OF DOLL CLUBS INC                                      50
# UNIVERSITY OF FLORIDA                                                    50
# Name: count, dtype: int64

# %%
# Look at CLASSIFICATION value counts to identify and replace with "Other"
class_counts = application_df['CLASSIFICATION'].value_counts()
class_counts
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: count, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
class_counts[class_counts >1]
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: count, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
classifications_to_replace = list(class_counts[class_counts < 2000].index)

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")

# Check to make sure replacement was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# Other     6062
# C1200     4837
# Name: count, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
numeric_app_df = pd.get_dummies(application_df)
numeric_app_df.head()
# Out:
#    STATUS  ASK_AMT  IS_SUCCESSFUL  NAME_AIR FORCE ASSOCIATION  \
# 0       1     5000              1                       False
# 1       1   108590              1                       False
# 2       1     5000              0                       False
# 3       1     6692              1                       False
# 4       1   142590              1                       False
#
#    NAME_ALPHA PHI SIGMA  NAME_AMATEUR ATHLETIC UNION OF THE UNITED STATES  \
# 0                 False                                             False
# 1                 False                                             False
# 2                 False                                             False
# 3                 False                                             False
# 4                 False                                             False
#
#    NAME_AMATEUR ATHLETIC UNION OF THE UNITED STATES INC  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    NAME_AMERICAN ASSOCIATION OF UNIVERSITY WOMEN  \
# 0                                          False
# 1                                          False
# 2                                          False
# 3                                          False
# 4                                          False
#
#    NAME_CALIFORNIA GARDEN CLUBS INC  NAME_CISD EDUCATIONAL SUPPORT GROUPS INC  \
# 0                             False                                     False
# 1                             False                                     False
# 2                             False                                     False
# 3                             False                                     False
# 4                             False                                     False
#
#    ...  INCOME_AMT_1-9999  INCOME_AMT_10000-24999  INCOME_AMT_100000-499999  \
# 0  ...              False                   False                     False
# 1  ...               True                   False                     False
# 2  ...              False                   False                     False
# 3  ...              False                    True                     False
# 4  ...              False                   False                      True
#
#    INCOME_AMT_10M-50M  INCOME_AMT_1M-5M  INCOME_AMT_25000-99999  \
# 0               False             False                   False
# 1               False             False                   False
# 2               False             False                   False
# 3               False             False                   False
# 4               False             False                   False
#
#    INCOME_AMT_50M+  INCOME_AMT_5M-10M  SPECIAL_CONSIDERATIONS_N  \
# 0            False              False                      True
# 1            False              False                      True
# 2            False              False                      True
# 3            False              False                      True
# 4            False              False                      True
#
#    SPECIAL_CONSIDERATIONS_Y
# 0                     False
# 1                     False
# 2                     False
# 3                     False
# 4                     False
#
# [5 rows x 102 columns]

# %%
# Split our preprocessed data into our features and target arrays
X = numeric_app_df.drop(columns='IS_SUCCESSFUL', axis=1)
y = numeric_app_df['IS_SUCCESSFUL']

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, stratify=y)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
input_features = X_train_scaled.shape[1]
hidden_nodes_1 = 8
hidden_nodes_2 = 32
hidden_nodes_3 = 16

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_1, input_dim=input_features, activation='relu'))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_2, activation='sigmoid'))
nn.add(tf.keras.layers.Dense(units=hidden_nodes_3, activation='sigmoid'))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 8)                 816
#
#  dense_1 (Dense)             (None, 32)                288
#
#  dense_2 (Dense)             (None, 16)                528
#
#  dense_3 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 1649 (6.44 KB)
# Trainable params: 1649 (6.44 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 3s 2ms/step - loss: 0.5580 - accuracy: 0.7220
# Epoch 2/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4923 - accuracy: 0.7609
# Epoch 3/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4864 - accuracy: 0.7607
# Epoch 4/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4837 - accuracy: 0.7640
# Epoch 5/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4825 - accuracy: 0.7645
# Epoch 6/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.4808 - accuracy: 0.7653
# Epoch 7/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.4804 - accuracy: 0.7651
# Epoch 8/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4793 - accuracy: 0.7654
# Epoch 9/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.4793 - accuracy: 0.7655
# Epoch 10/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4783 - accuracy: 0.7654
# Epoch 11/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4779 - accuracy: 0.7660
# Epoch 12/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.4774 - accuracy: 0.7653
# Epoch 13/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4768 - accuracy: 0.7677
# Epoch 14/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.4769 - accuracy: 0.7668
# Epoch 15/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.4765 - accuracy: 0.7664
# Epoch 16/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.4757 - accuracy: 0.7670
# Epoch 17/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4751 - accuracy: 0.7676
# Epoch 18/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.4747 - accuracy: 0.7674
# Epoch 19/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4751 - accuracy: 0.7661
# Epoch 20/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4749 - accuracy: 0.7671
# Epoch 21/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4746 - accuracy: 0.7683
# Epoch 22/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.4743 - accuracy: 0.7678
# Epoch 23/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4738 - accuracy: 0.7675
# Epoch 24/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4740 - accuracy: 0.7679
# Epoch 25/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4738 - accuracy: 0.7678
# Epoch 26/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.4734 - accuracy: 0.7682
# Epoch 27/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4733 - accuracy: 0.7683
# Epoch 28/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4732 - accuracy: 0.7674
# Epoch 29/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.4732 - accuracy: 0.7684
# Epoch 30/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.4729 - accuracy: 0.7670
# Epoch 31/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4731 - accuracy: 0.7678
# Epoch 32/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4726 - accuracy: 0.7690
# Epoch 33/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4724 - accuracy: 0.7682
# Epoch 34/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.4727 - accuracy: 0.7685
# Epoch 35/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.4723 - accuracy: 0.7676
# Epoch 36/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4723 - accuracy: 0.7673
# Epoch 37/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.4718 - accuracy: 0.7687
# Epoch 38/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.4719 - accuracy: 0.7685
# Epoch 39/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.4720 - accuracy: 0.7681
# Epoch 40/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.4718 - accuracy: 0.7689
# Epoch 41/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.4717 - accuracy: 0.7682
# Epoch 42/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4716 - accuracy: 0.7687
# Epoch 43/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4714 - accuracy: 0.7686
# Epoch 44/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.4713 - accuracy: 0.7691
# Epoch 45/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.4714 - accuracy: 0.7691
# Epoch 46/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.4709 - accuracy: 0.7686
# Epoch 47/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4710 - accuracy: 0.7690
# Epoch 48/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4708 - accuracy: 0.7696
# Epoch 49/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4704 - accuracy: 0.7694
# Epoch 50/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4709 - accuracy: 0.7694
# Epoch 51/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.4705 - accuracy: 0.7689
# Epoch 52/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.4707 - accuracy: 0.7689
# Epoch 53/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4704 - accuracy: 0.7696
# Epoch 54/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.4705 - accuracy: 0.7694
# Epoch 55/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.4702 - accuracy: 0.7694
# Epoch 56/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4699 - accuracy: 0.7695
# Epoch 57/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4702 - accuracy: 0.7691
# Epoch 58/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4701 - accuracy: 0.7701
# Epoch 59/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4696 - accuracy: 0.7696
# Epoch 60/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.4698 - accuracy: 0.7691
# Epoch 61/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4700 - accuracy: 0.7691
# Epoch 62/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.4696 - accuracy: 0.7693
# Epoch 63/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4697 - accuracy: 0.7696
# Epoch 64/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4693 - accuracy: 0.7708
# Epoch 65/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4695 - accuracy: 0.7691
# Epoch 66/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4694 - accuracy: 0.7706
# Epoch 67/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4696 - accuracy: 0.7699
# Epoch 68/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4691 - accuracy: 0.7699
# Epoch 69/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.4690 - accuracy: 0.7697
# Epoch 70/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.4694 - accuracy: 0.7708
# Epoch 71/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4691 - accuracy: 0.7694
# Epoch 72/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4692 - accuracy: 0.7694
# Epoch 73/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4689 - accuracy: 0.7702
# Epoch 74/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4689 - accuracy: 0.7694
# Epoch 75/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4687 - accuracy: 0.7699
# Epoch 76/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.4688 - accuracy: 0.7691
# Epoch 77/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.4684 - accuracy: 0.7701
# Epoch 78/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4684 - accuracy: 0.7700
# Epoch 79/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4685 - accuracy: 0.7701
# Epoch 80/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.4689 - accuracy: 0.7706
# Epoch 81/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.4685 - accuracy: 0.7705
# Epoch 82/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.4684 - accuracy: 0.7696
# Epoch 83/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.4682 - accuracy: 0.7704
# Epoch 84/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4684 - accuracy: 0.7695
# Epoch 85/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4682 - accuracy: 0.7704
# Epoch 86/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4685 - accuracy: 0.7699
# Epoch 87/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4682 - accuracy: 0.7697
# Epoch 88/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4682 - accuracy: 0.7704
# Epoch 89/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.4679 - accuracy: 0.7703
# Epoch 90/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.4679 - accuracy: 0.7710
# Epoch 91/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4678 - accuracy: 0.7702
# Epoch 92/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4678 - accuracy: 0.7699
# Epoch 93/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4680 - accuracy: 0.7708
# Epoch 94/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4682 - accuracy: 0.7701
# Epoch 95/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4679 - accuracy: 0.7700
# Epoch 96/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4677 - accuracy: 0.7711
# Epoch 97/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.4676 - accuracy: 0.7704
# Epoch 98/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.4678 - accuracy: 0.7701
# Epoch 99/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.4675 - accuracy: 0.7699
# Epoch 100/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4679 - accuracy: 0.7704

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.4800 - accuracy: 0.7606 - 499ms/epoch - 2ms/step
# Loss: 0.48000460863113403, Accuracy: 0.7605831027030945

# %%
# Export our model to HDF5 file
# source 01 to download file from google collab
from google.colab import files
nn.save('../models/AlphabetSoupCharity_Optimization2.h5')
files.download('../models/AlphabetSoupCharity_Optimization2.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
